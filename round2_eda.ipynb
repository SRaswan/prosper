# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate

# %%
df_or = pd.read_csv("round-2-island-data-bottle/prices_round_2_day_-1.csv", sep = ";").drop(['timestamp'], axis=1)
#df_or = pd.concat([df_or, pd.read_csv("round-2-island-data-bottle/prices_round_2_day_0.csv", sep = ";")])
#df_or = pd.concat([df_or, pd.read_csv("round-2-island-data-bottle/prices_round_2_day_1.csv", sep = ";")])
df_or
# Out:
#        ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  IMPORT_TARIFF   SUNLIGHT  \
# 0      1200.00             1.5           10.5           -2.0  2500.0000
# 1      1201.75             1.5            9.5           -2.0  2499.4197
# 2      1201.75             1.5            9.5           -2.0  2498.8457
# 3      1201.75             1.5            9.5           -2.0  2498.2780
# 4      1201.75             1.5            9.5           -2.0  2497.7166
# ...        ...             ...            ...            ...        ...
# 9996   1227.75             1.4            8.5           -3.0  3901.9530
# 9997   1226.75             1.4            8.5           -3.0  3901.4612
# 9998   1227.75             1.4            8.5           -3.0  3900.9720
# 9999   1228.00             1.4            8.5           -3.0  3900.4849
# 10000  1228.00             1.4            8.5           -3.0  3900.0000
#
#         HUMIDITY  DAY
# 0      79.000000   -1
# 1      79.004100   -1
# 2      79.008210   -1
# ...

# %%
df_or['ORCHIDS'].plot()
# Out:
# <Axes: >

# %%
df_or['SUNLIGHT'].plot()
# Out:
# <Axes: >

# %%
plt.plot(integrate.cumulative_trapezoid(df_or['SUNLIGHT']))

# %%
df_or['SUNLIGHT'].mean()
# Out:
# 3619.7501030396957

# %%
df_or['HUMIDITY'].plot()
# Out:
# <Axes: >

# %%
df_or.corr()
# Out:
#                  ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  IMPORT_TARIFF  \
# ORCHIDS         1.000000        0.103595       0.187337      -0.137264
# TRANSPORT_FEES  0.103595        1.000000       0.156977      -0.084847
# EXPORT_TARIFF   0.187337        0.156977       1.000000      -0.077444
# IMPORT_TARIFF  -0.137264       -0.084847      -0.077444       1.000000
# SUNLIGHT        0.632492       -0.090303       0.357167      -0.404930
# HUMIDITY        0.658801        0.078135       0.273492      -0.098170
# DAY                  NaN             NaN            NaN            NaN
#
#                 SUNLIGHT  HUMIDITY  DAY
# ORCHIDS         0.632492  0.658801  NaN
# TRANSPORT_FEES -0.090303  0.078135  NaN
# EXPORT_TARIFF   0.357167  0.273492  NaN
# IMPORT_TARIFF  -0.404930 -0.098170  NaN
# SUNLIGHT        1.000000  0.681110  NaN
# HUMIDITY        0.681110  1.000000  NaN
# DAY                  NaN       NaN  NaN

# %%
df_ob = pd.read_csv("9809c9b9-9164-4c3e-80f4-94599b51ce36.csv", sep=';')
df_ob
# Out:
#       day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       1        100  STARFRUIT         5048             1       5047.0
# 1       1        100    ORCHIDS         1094            16       1093.0
# 2       1        100  AMETHYSTS         9998             2       9996.0
# 3       1        200  AMETHYSTS         9996             2       9995.0
# 4       1        200    ORCHIDS         1093             6       1092.0
# ...   ...        ...        ...          ...           ...          ...
# 2992    1      99800  AMETHYSTS         9996             1       9995.0
# 2993    1      99800    ORCHIDS         1068             8       1067.0
# 2994    1      99900  STARFRUIT         5043            28          NaN
# 2995    1      99900    ORCHIDS         1067             7       1066.0
# 2996    1      99900  AMETHYSTS         9995            28          NaN
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
df_ob_or = df_ob[df_ob['product'] == 'ORCHIDS']
df_ob_or
# Out:
#       day  timestamp  product  bid_price_1  bid_volume_1  bid_price_2  \
# 1       1        100  ORCHIDS         1094            16       1093.0
# 4       1        200  ORCHIDS         1093             6       1092.0
# 8       1        300  ORCHIDS         1093            10       1092.0
# 10      1        400  ORCHIDS         1093            10       1092.0
# 13      1        500  ORCHIDS         1094             5       1093.0
# ...   ...        ...      ...          ...           ...          ...
# 2983    1      99500  ORCHIDS         1067             5       1066.0
# 2985    1      99600  ORCHIDS         1068             7       1067.0
# 2988    1      99700  ORCHIDS         1068             5       1067.0
# 2993    1      99800  ORCHIDS         1068             8       1067.0
# 2995    1      99900  ORCHIDS         1067             7       1066.0
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
or_mp = df_ob_or['mid_price']
or_mp.plot()
# Out:
# <Axes: >
