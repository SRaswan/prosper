# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("prices_round_1_day_-2.csv", sep = ";")
df1
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -2          0  AMETHYSTS         9996             1       9995.0
# 1       -2          0  STARFRUIT         4997            26          NaN
# 2       -2        100  AMETHYSTS        10000             5       9995.0
# 3       -2        100  STARFRUIT         5000             5       4998.0
# 4       -2        200  STARFRUIT         4997             1       4996.0
# ...    ...        ...        ...          ...           ...          ...
# 19995   -2     999700  AMETHYSTS         9995            22          NaN
# 19996   -2     999800  STARFRUIT         5041             1       5040.0
# 19997   -2     999800  AMETHYSTS         9996             1       9995.0
# 19998   -2     999900  STARFRUIT         5044             4       5040.0
# 19999   -2     999900  AMETHYSTS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
df2 = pd.read_csv("prices_round_1_day_-1.csv", sep = ";")
df2
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -1          0  AMETHYSTS        10002             1       9996.0
# 1       -1          0  STARFRUIT         5045             1       5040.0
# 2       -1        100  STARFRUIT         5040            24          NaN
# 3       -1        100  AMETHYSTS         9996             2       9995.0
# 4       -1        200  AMETHYSTS         9995            20          NaN
# ...    ...        ...        ...          ...           ...          ...
# 19995   -1     999700  AMETHYSTS         9995            26          NaN
# 19996   -1     999800  STARFRUIT         5036            20          NaN
# 19997   -1     999800  AMETHYSTS         9995            20          NaN
# 19998   -1     999900  AMETHYSTS         9996             2       9995.0
# 19999   -1     999900  STARFRUIT         5036            31          NaN
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
df3 = pd.read_csv("prices_round_1_day_0.csv", sep = ";")
df3
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0        0          0  AMETHYSTS         9998             1       9995.0
# 1        0          0  STARFRUIT         5036            30          NaN
# 2        0        100  AMETHYSTS         9996             1       9995.0
# 3        0        100  STARFRUIT         5041             4       5037.0
# 4        0        200  AMETHYSTS         9996             1       9995.0
# ...    ...        ...        ...          ...           ...          ...
# 19995    0     999700  STARFRUIT         5053             1       5048.0
# 19996    0     999800  STARFRUIT         5047            27          NaN
# 19997    0     999800  AMETHYSTS         9995            27          NaN
# 19998    0     999900  STARFRUIT         5048             2       5047.0
# 19999    0     999900  AMETHYSTS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
df = pd.concat([df1, df2, df3], ignore_index=True)

df
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -2          0  AMETHYSTS         9996             1       9995.0
# 1       -2          0  STARFRUIT         4997            26          NaN
# 2       -2        100  AMETHYSTS        10000             5       9995.0
# 3       -2        100  STARFRUIT         5000             5       4998.0
# 4       -2        200  STARFRUIT         4997             1       4996.0
# ...    ...        ...        ...          ...           ...          ...
# 59995    0     999700  STARFRUIT         5053             1       5048.0
# 59996    0     999800  STARFRUIT         5047            27          NaN
# 59997    0     999800  AMETHYSTS         9995            27          NaN
# 59998    0     999900  STARFRUIT         5048             2       5047.0
# 59999    0     999900  AMETHYSTS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
df_starfruit

df_starfruit["timestamp"] = [i * 100 for i in range(len(df_starfruit))]
df_starfruit
# Out:
# /tmp/ipykernel_156/2614741664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_starfruit["timestamp"] = [i * 100 for i in range(len(df_starfruit))]
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 1       -2          0  STARFRUIT         4997            26          NaN
# 3       -2        100  STARFRUIT         5000             5       4998.0
# 4       -2        200  STARFRUIT         4997             1       4996.0
# 7       -2        300  STARFRUIT         4996            27          NaN
# 9       -2        400  STARFRUIT         4995            20          NaN
# ...    ...        ...        ...          ...           ...          ...
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_starfruit["timestamp"].to_numpy(), df_starfruit["mid_price"].to_numpy(), label="Starfruit", marker='x')
plt.title("Mid Prices of Starfruit Over Time")
plt.xlabel("Timestamp")
plt.ylabel("Mid Price")
plt.grid(True)
plt.legend()
plt.show()

# %%
df_amethysts["timestamp"] = [i * 100 for i in range(len(df_amethysts))]
df_amethysts
# Out:
# /tmp/ipykernel_156/389398021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_amethysts["timestamp"] = [i * 100 for i in range(len(df_amethysts))]
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -2          0  AMETHYSTS         9996             1       9995.0
# 2       -2        100  AMETHYSTS        10000             5       9995.0
# 5       -2        200  AMETHYSTS         9996             1       9995.0
# 6       -2        300  AMETHYSTS         9996             1       9995.0
# 8       -2        400  AMETHYSTS         9995            20          NaN
# ...    ...        ...        ...          ...           ...          ...
# ...

# %%
dft = pd.read_csv("trades_round_1_day_-2_nn.csv", sep = ";")
dft
# Out:
#       timestamp  buyer  seller     symbol   currency   price  quantity
# 0             0    NaN     NaN  AMETHYSTS  SEASHELLS  9996.0         1
# 1             0    NaN     NaN  STARFRUIT  SEASHELLS  5003.0         1
# 2             0    NaN     NaN  AMETHYSTS  SEASHELLS  9996.0         1
# 3           100    NaN     NaN  STARFRUIT  SEASHELLS  5004.0         6
# 4           900    NaN     NaN  STARFRUIT  SEASHELLS  5001.0         2
# ...         ...    ...     ...        ...        ...     ...       ...
# 5458     998000    NaN     NaN  STARFRUIT  SEASHELLS  5046.0         4
# 5459     998900    NaN     NaN  STARFRUIT  SEASHELLS  5046.0         1
# 5460     999000    NaN     NaN  STARFRUIT  SEASHELLS  5047.0         1
# 5461     999800    NaN     NaN  AMETHYSTS  SEASHELLS  9998.0         1
# 5462     999900    NaN     NaN  STARFRUIT  SEASHELLS  5044.0         4
#
# [5463 rows x 7 columns]

# %%
dft1 = pd.read_csv("trades_round_1_day_-1_nn.csv", sep = ";")
dft1
# Out:
#       timestamp  buyer  seller     symbol   currency    price  quantity
# 0             0    NaN     NaN  STARFRUIT  SEASHELLS   5047.0        13
# 1             0    NaN     NaN  STARFRUIT  SEASHELLS   5047.0         1
# 2             0    NaN     NaN  AMETHYSTS  SEASHELLS  10004.0         1
# 3          1100    NaN     NaN  AMETHYSTS  SEASHELLS   9996.0         2
# 4          1700    NaN     NaN  AMETHYSTS  SEASHELLS  10002.0         1
# ...         ...    ...     ...        ...        ...      ...       ...
# 5365     999200    NaN     NaN  STARFRUIT  SEASHELLS   5038.0         7
# 5366     999200    NaN     NaN  STARFRUIT  SEASHELLS   5043.0         1
# 5367     999200    NaN     NaN  STARFRUIT  SEASHELLS   5038.0         1
# 5368     999500    NaN     NaN  STARFRUIT  SEASHELLS   5041.0         2
# 5369     999600    NaN     NaN  AMETHYSTS  SEASHELLS   9998.0         1
#
# [5370 rows x 7 columns]

# %%
dft2 = pd.read_csv("trades_round_1_day_-2_nn.csv", sep = ";")
dft2
# Out:
#       timestamp  buyer  seller     symbol   currency   price  quantity
# 0             0    NaN     NaN  AMETHYSTS  SEASHELLS  9996.0         1
# 1             0    NaN     NaN  STARFRUIT  SEASHELLS  5003.0         1
# 2             0    NaN     NaN  AMETHYSTS  SEASHELLS  9996.0         1
# 3           100    NaN     NaN  STARFRUIT  SEASHELLS  5004.0         6
# 4           900    NaN     NaN  STARFRUIT  SEASHELLS  5001.0         2
# ...         ...    ...     ...        ...        ...     ...       ...
# 5458     998000    NaN     NaN  STARFRUIT  SEASHELLS  5046.0         4
# 5459     998900    NaN     NaN  STARFRUIT  SEASHELLS  5046.0         1
# 5460     999000    NaN     NaN  STARFRUIT  SEASHELLS  5047.0         1
# 5461     999800    NaN     NaN  AMETHYSTS  SEASHELLS  9998.0         1
# 5462     999900    NaN     NaN  STARFRUIT  SEASHELLS  5044.0         4
#
# [5463 rows x 7 columns]

# %%
dftrade = pd.concat([dft, dft1, dft2], ignore_index=True)

dftrade
# Out:
#        timestamp  buyer  seller     symbol   currency   price  quantity
# 0              0    NaN     NaN  AMETHYSTS  SEASHELLS  9996.0         1
# 1              0    NaN     NaN  STARFRUIT  SEASHELLS  5003.0         1
# 2              0    NaN     NaN  AMETHYSTS  SEASHELLS  9996.0         1
# 3            100    NaN     NaN  STARFRUIT  SEASHELLS  5004.0         6
# 4            900    NaN     NaN  STARFRUIT  SEASHELLS  5001.0         2
# ...          ...    ...     ...        ...        ...     ...       ...
# 16291     998000    NaN     NaN  STARFRUIT  SEASHELLS  5046.0         4
# 16292     998900    NaN     NaN  STARFRUIT  SEASHELLS  5046.0         1
# 16293     999000    NaN     NaN  STARFRUIT  SEASHELLS  5047.0         1
# 16294     999800    NaN     NaN  AMETHYSTS  SEASHELLS  9998.0         1
# 16295     999900    NaN     NaN  STARFRUIT  SEASHELLS  5044.0         4
#
# [16296 rows x 7 columns]

# %%
df_star = dftrade[dftrade.get("symbol") == "STARFRUIT"]
df_star
# Out:
#        timestamp  buyer  seller     symbol   currency   price  quantity
# 1              0    NaN     NaN  STARFRUIT  SEASHELLS  5003.0         1
# 3            100    NaN     NaN  STARFRUIT  SEASHELLS  5004.0         6
# 4            900    NaN     NaN  STARFRUIT  SEASHELLS  5001.0         2
# 5           1000    NaN     NaN  STARFRUIT  SEASHELLS  4997.0         2
# 6           1100    NaN     NaN  STARFRUIT  SEASHELLS  4997.0         1
# ...          ...    ...     ...        ...        ...     ...       ...
# 16290     998000    NaN     NaN  STARFRUIT  SEASHELLS  5043.0         1
# 16291     998000    NaN     NaN  STARFRUIT  SEASHELLS  5046.0         4
# 16292     998900    NaN     NaN  STARFRUIT  SEASHELLS  5046.0         1
# 16293     999000    NaN     NaN  STARFRUIT  SEASHELLS  5047.0         1
# 16295     999900    NaN     NaN  STARFRUIT  SEASHELLS  5044.0         4
#
# [9021 rows x 7 columns]

# %%
df_am = dftrade[dftrade.get("symbol") == "AMETHYSTS"]
df_am = df_am.reset_index()
df_am
# Out:
#       index  timestamp  buyer  seller     symbol   currency    price  quantity
# 0         0          0    NaN     NaN  AMETHYSTS  SEASHELLS   9996.0         1
# 1         2          0    NaN     NaN  AMETHYSTS  SEASHELLS   9996.0         1
# 2         8       1500    NaN     NaN  AMETHYSTS  SEASHELLS  10004.0         1
# 3        14       2500    NaN     NaN  AMETHYSTS  SEASHELLS   9998.0         1
# 4        16       3200    NaN     NaN  AMETHYSTS  SEASHELLS   9996.0         1
# ...     ...        ...    ...     ...        ...        ...      ...       ...
# 7270  16281     996700    NaN     NaN  AMETHYSTS  SEASHELLS  10004.0         1
# 7271  16283     996800    NaN     NaN  AMETHYSTS  SEASHELLS   9996.0         2
# 7272  16284     997000    NaN     NaN  AMETHYSTS  SEASHELLS  10004.0         1
# 7273  16288     997700    NaN     NaN  AMETHYSTS  SEASHELLS   9996.0         1
# 7274  16294     999800    NaN     NaN  AMETHYSTS  SEASHELLS   9998.0         1
#
# [7275 rows x 8 columns]

# %%
def convert_time(time):
    return time*

# %%
import numpy as np
sample_rate = 100


timestamps_downsampled = df_amethysts["timestamp"].to_numpy()[::sample_rate]
mid_prices_downsampled = df_amethysts["mid_price"].to_numpy()[::sample_rate]


window_size = 100  
moving_average = np.convolve(df_amethysts["mid_price"], np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(30, 6))  


plt.plot(timestamps_downsampled, mid_prices_downsampled, label="Amethysts", linestyle='-')


plt.title("Mid Prices of Amethysts Over Time")
plt.xlabel("Timestamp")
plt.ylabel("Mid Price")
plt.grid(True)
plt.legend()
plt.show()
